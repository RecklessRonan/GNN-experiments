# %%
with open('log.txt', 'r') as f:
    log = f.readlines()

# %%
for l in log:
    if 'GGCN' in l or 'Test acc' in l or 'Test std' in l:
        print(l)
# Out:
# ['nohup: ignoring input\n',
#  'Using backend: pytorch\n',
#  'cuda:0 pretrained/GGCN_wisconsin_04_14_02_15.pt\n',
#  'Epoch:0001 train loss:1.594 acc:41.67 | val loss:1.552 acc:42.50\n',
#  'Epoch:0002 train loss:1.560 acc:49.17 | val loss:1.520 acc:30.00\n',
#  'Epoch:0003 train loss:1.525 acc:40.00 | val loss:1.488 acc:28.75\n',
#  'Epoch:0004 train loss:1.489 acc:35.83 | val loss:1.458 acc:26.25\n',
#  'Epoch:0005 train loss:1.453 acc:34.17 | val loss:1.431 acc:27.50\n',
#  'Epoch:0006 train loss:1.419 acc:35.83 | val loss:1.409 acc:30.00\n',
#  'Epoch:0007 train loss:1.389 acc:40.00 | val loss:1.392 acc:36.25\n',
#  'Epoch:0008 train loss:1.363 acc:46.67 | val loss:1.381 acc:46.25\n',
#  'Epoch:0009 train loss:1.342 acc:52.50 | val loss:1.373 acc:53.75\n',
#  'Epoch:0010 train loss:1.324 acc:59.17 | val loss:1.365 acc:63.75\n',
#  'Epoch:0011 train loss:1.308 acc:68.33 | val loss:1.356 acc:65.00\n',
#  'Epoch:0012 train loss:1.292 acc:68.33 | val loss:1.346 acc:57.50\n',
# ...
