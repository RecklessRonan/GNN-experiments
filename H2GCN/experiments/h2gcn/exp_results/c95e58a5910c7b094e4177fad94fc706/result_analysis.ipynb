# %%
import pandas as pd

# %%
result = pd.read_csv('gcn_results_skip6.csv', header=0, encoding='utf-8')
result_grouped = result.groupby(['Feature', 'Model Args'])['Test Acc'].mean().reset_index()
result_grouped
# Out:
#                   Feature                                         Model Args  \
# 0    chameleon-unmodified  --model mlp_norm --learning_rate 0.02 --weight...
# 1    chameleon-unmodified  --model mlp_norm --learning_rate 0.02 --weight...
# 2    chameleon-unmodified  --model mlp_norm --learning_rate 0.02 --weight...
# 3    chameleon-unmodified  --model mlp_norm --learning_rate 0.02 --weight...
# 4    chameleon-unmodified  --model mlp_norm --learning_rate 0.02 --weight...
# ..                    ...                                                ...
# 139  wisconsin-unmodified  --model mlp_norm --learning_rate 0.02 --weight...
# 140  wisconsin-unmodified  --model mlp_norm --learning_rate 0.02 --weight...
# 141  wisconsin-unmodified  --model mlp_norm --learning_rate 0.02 --weight...
# 142  wisconsin-unmodified  --model mlp_norm --learning_rate 0.02 --weight...
# 143  wisconsin-unmodified  --model mlp_norm --learning_rate 0.02 --weight...
#
#      Test Acc
# 0    0.444079
# ...

# %%
result_grouped.to_csv('result_skip6.csv', header=True, index=False)

# %%
result = pd.read_csv('gcn_results1.csv', header=0, encoding='utf-8')
result_grouped = result.groupby(['Feature', 'Model Args'])['Test Acc'].mean().reset_index()
result_grouped
# Out:
#                     Feature                                     Model Args  \
# 0      chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 1      chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 2      chameleon-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 3        cornell-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 4        cornell-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 5        cornell-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 6           film-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 7           film-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 8           film-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 9   ind.citeseer-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 10  ind.citeseer-unmodified  --model gcn --hidden1 64 --early_stopping 200
# ...

# %%
result_new = pd.read_csv('gcn_results2.csv', header=0, encoding='utf-8')
result_new_grouped = result_new.groupby(['Feature', 'Model Args'])['Test Acc'].mean().reset_index()
result_new_grouped
# Out:
#                     Feature  \
# 0      chameleon-unmodified
# 1      chameleon-unmodified
# 2        cornell-unmodified
# 3        cornell-unmodified
# 4           film-unmodified
# 5           film-unmodified
# 6   ind.citeseer-unmodified
# 7   ind.citeseer-unmodified
# 8       ind.cora-unmodified
# 9       ind.cora-unmodified
# 10    ind.pubmed-unmodified
# 11    ind.pubmed-unmodified
# 12      squirrel-unmodified
# 13      squirrel-unmodified
# 14         texas-unmodified
# 15         texas-unmodified
# 16     wisconsin-unmodified
# 17     wisconsin-unmodified
#
#                                            Model Args  Test Acc
# 0   --model gcn --epochs 200 --hidden1 16 --early_...  0.549561
# 1   --model gcn --epochs 300 --hidden1 16 --early_...  0.550219
# 2   --model gcn --epochs 200 --hidden1 16 --early_...  0.589189
# 3   --model gcn --epochs 300 --hidden1 16 --early_...  0.589189
# 4   --model gcn --epochs 200 --hidden1 16 --early_...  0.295921
# ...

# %%
# alpha=0.1, beta=0.1
result_new = pd.read_csv('gcn_results3.csv', header=0, encoding='utf-8')
result_new_grouped = result_new.groupby(['Feature', 'Model Args'])['Test Acc'].mean().reset_index()
result_new_grouped
# Out:
#                     Feature                                     Model Args  \
# 0      chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 1      chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 2      chameleon-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 3        cornell-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 4        cornell-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 5        cornell-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 6           film-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 7           film-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 8           film-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 9   ind.citeseer-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 10  ind.citeseer-unmodified  --model gcn --hidden1 64 --early_stopping 200
# ...

# %%
# alpha=1, beta=1
result_new = pd.read_csv('gcn_results4.csv', header=0, encoding='utf-8')
result_new_grouped = result_new.groupby(['Feature', 'Model Args'])['Test Acc'].mean().reset_index()
result_new_grouped
# Out:
#                     Feature                                     Model Args  \
# 0      chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 1      chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 2      chameleon-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 3        cornell-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 4        cornell-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 5        cornell-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 6           film-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 7           film-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 8           film-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 9   ind.citeseer-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 10  ind.citeseer-unmodified  --model gcn --hidden1 64 --early_stopping 200
# ...

# %%
# alpha=1, beta=2
result_new = pd.read_csv('gcn_results5.csv', header=0, encoding='utf-8')
result_new_grouped = result_new.groupby(['Feature', 'Model Args'])['Test Acc'].mean().reset_index()
result_new_grouped
# Out:
#                     Feature                                     Model Args  \
# 0      chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 1      chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 2      chameleon-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 3        cornell-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 4        cornell-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 5        cornell-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 6           film-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 7           film-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 8           film-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 9   ind.citeseer-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 10  ind.citeseer-unmodified  --model gcn --hidden1 64 --early_stopping 200
# ...

# %%
# alpha=0.1, beta=1.5
result_new = pd.read_csv('gcn_results6.csv', header=0, encoding='utf-8')
result_new_grouped = result_new.groupby(['Feature', 'Model Args'])['Test Acc'].mean().reset_index()
result_new_grouped
# Out:
#                     Feature                                     Model Args  \
# 0      chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 1      chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 2      chameleon-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 3        cornell-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 4        cornell-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 5        cornell-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 6           film-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 7           film-unmodified  --model gcn --hidden1 64 --early_stopping 200
# 8           film-unmodified   --model gcn --hidden1 64 --early_stopping 40
# 9   ind.citeseer-unmodified  --model gcn --hidden1 64 --early_stopping 100
# 10  ind.citeseer-unmodified  --model gcn --hidden1 64 --early_stopping 200
# ...
