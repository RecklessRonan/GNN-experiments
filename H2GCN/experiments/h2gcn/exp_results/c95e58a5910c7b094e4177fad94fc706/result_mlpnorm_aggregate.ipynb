# %%
import pandas as pd

# %%
result1 = pd.read_csv('result_mlpnorm1.csv', header=0, encoding='utf-8')
result1
# Out:
#                     Feature  \
# 0      chameleon-unmodified
# 1      chameleon-unmodified
# 2      chameleon-unmodified
# 3      chameleon-unmodified
# 4      chameleon-unmodified
# 5      chameleon-unmodified
# 6        cornell-unmodified
# 7        cornell-unmodified
# 8        cornell-unmodified
# 9        cornell-unmodified
# 10       cornell-unmodified
# 11       cornell-unmodified
# 12          film-unmodified
# 13          film-unmodified
# 14          film-unmodified
# 15          film-unmodified
# 16          film-unmodified
# 17          film-unmodified
# 18  ind.citeseer-unmodified
# 19  ind.citeseer-unmodified
# 20  ind.citeseer-unmodified
# 21  ind.citeseer-unmodified
# 22  ind.citeseer-unmodified
# 23  ind.citeseer-unmodified
# 24      ind.cora-unmodified
# 25      ind.cora-unmodified
# 26      ind.cora-unmodified
# 27      ind.cora-unmodified
# 28      ind.cora-unmodified
# 29      ind.cora-unmodified
# 30    ind.pubmed-unmodified
# 31    ind.pubmed-unmodified
# ...

# %%
result2 = pd.read_csv('result_mlpnorm2.csv', header=0, encoding='utf-8')
result2
# Out:
#                     Feature  \
# 0      chameleon-unmodified
# 1      chameleon-unmodified
# 2      chameleon-unmodified
# 3      chameleon-unmodified
# 4      chameleon-unmodified
# 5      chameleon-unmodified
# 6        cornell-unmodified
# 7        cornell-unmodified
# 8        cornell-unmodified
# 9        cornell-unmodified
# 10       cornell-unmodified
# 11       cornell-unmodified
# 12          film-unmodified
# 13          film-unmodified
# 14          film-unmodified
# 15          film-unmodified
# 16          film-unmodified
# 17          film-unmodified
# 18  ind.citeseer-unmodified
# 19  ind.citeseer-unmodified
# 20  ind.citeseer-unmodified
# 21  ind.citeseer-unmodified
# 22  ind.citeseer-unmodified
# 23  ind.citeseer-unmodified
# 24      ind.cora-unmodified
# 25      ind.cora-unmodified
# 26      ind.cora-unmodified
# 27      ind.cora-unmodified
# 28      ind.cora-unmodified
# 29      ind.cora-unmodified
# 30    ind.pubmed-unmodified
# 31    ind.pubmed-unmodified
# ...

# %%
result = pd.concat([result1, result2], axis=0)

# %%
result = result.sort_values(by=['Feature', 'Model Args'])
result
# Out:
#                  Feature                                         Model Args  \
# 0   chameleon-unmodified  --model mlp_norm --hidden1 64 --early_stopping...
# 1   chameleon-unmodified  --model mlp_norm --hidden1 64 --early_stopping...
# 2   chameleon-unmodified  --model mlp_norm --hidden1 64 --early_stopping...
# 3   chameleon-unmodified  --model mlp_norm --hidden1 64 --early_stopping...
# 4   chameleon-unmodified  --model mlp_norm --hidden1 64 --early_stopping...
# ..                   ...                                                ...
# 49  wisconsin-unmodified  --model mlp_norm --hidden1 64 --early_stopping...
# 50  wisconsin-unmodified  --model mlp_norm --hidden1 64 --early_stopping...
# 51  wisconsin-unmodified  --model mlp_norm --hidden1 64 --early_stopping...
# 52  wisconsin-unmodified  --model mlp_norm --hidden1 64 --early_stopping...
# 53  wisconsin-unmodified  --model mlp_norm --hidden1 64 --early_stopping...
#
#     Test Acc
# 0   0.383333
# 1   0.385965
# ...

# %%
result.to_csv('result_mlpnorm_all.csv', header=True, index=False)
