# %%
import pandas as pd

# %%
result1 = pd.read_csv('result_mutiple1-1.csv', header=0, encoding='utf-8')
result1
# Out:
#                  Feature                                         Model Args  \
# 0   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 1   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 2   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 3   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 4   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# ..                   ...                                                ...
# 76  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 77  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 78  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
# 79  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
# 80  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
#
#     Test Acc
# 0   0.446053
# 1   0.377851
# ...

# %%
result2 = pd.read_csv('result_mutiple1.csv', header=0, encoding='utf-8')
result2
# Out:
#                  Feature                                         Model Args  \
# 0   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 1   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 2   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 3   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 4   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# ..                   ...                                                ...
# 76  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 77  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 78  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
# 79  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
# 80  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
#
#     Test Acc
# 0   0.562719
# 1   0.540570
# ...

# %%
result3 = pd.read_csv('result_mutiple2.csv', header=0, encoding='utf-8')
result3
# Out:
#                  Feature                                         Model Args  \
# 0   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 1   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 2   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 3   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 4   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# ..                   ...                                                ...
# 76  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 77  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 78  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
# 79  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
# 80  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
#
#     Test Acc
# 0   0.563597
# 1   0.540351
# ...

# %%
result4 = pd.read_csv('result_mutiple2-1.csv', header=0, encoding='utf-8')
result4
# Out:
#                  Feature                                         Model Args  \
# 0   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 1   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 2   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 3   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 4   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# ..                   ...                                                ...
# 76  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 77  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 78  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
# 79  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
# 80  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
#
#     Test Acc
# 0   0.207237
# 1   0.207675
# ...

# %%
result = pd.concat([result1, result2], axis=0)
result = pd.concat([result, result3], axis=0)
result = pd.concat([result, result4], axis=0)
result
# Out:
#                  Feature                                         Model Args  \
# 0   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 1   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 2   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 100 ...
# 3   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 4   chameleon-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# ..                   ...                                                ...
# 76  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 77  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 200 ...
# 78  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
# 79  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
# 80  wisconsin-unmodified  --model gcn --hidden1 64 --early_stopping 40  ...
#
#     Test Acc
# 0   0.446053
# 1   0.377851
# ...

# %%
result = result.sort_values(by=['Feature', 'Model Args'])

# %%
result.to_csv('result_mutiple_all.csv', header=True, index=False)
